# %%
import pandas as pd
import numpy as np
import random as rd
import seaborn as sbs
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from matplotlib import pyplot

# %%
#Opção para uso no GDrive
#from google.colab import drive

#drive.mount('/content/drive', force_remount=True)
#arquivo = '/content/drive/MyDrive/Colab Notebooks/waterdemand/data/DS_Agua_2017_2022.csv'
#drive.flush_and_unmount

# %%
file_data = 'DS_Agua_2017_2022.csv'
path_name='data/'
arquivo = f'{path_name}{file_data}'

# %%
dataset = pd.read_csv(arquivo, sep =';', encoding = 'latin1', decimal='.')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45240 entries, 1 to 45240
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DT_MEDICAO_HORA         45240 non-null  object
#  1   PRECIPITACAO            45240 non-null  float64
#  2   PRESSAO_ATMOSFERICA     45240 non-null  float64
#  3   TEMPERATURA_DO_AR_C     45240 non-null  float64
#  4   UMIDADE_RELATIVA_DO_AR  45240 non-null  float64
#  5   VELOCIDADE_VENTO        45240 non-null  float64
#  6   VL_MEDICAO              45240 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 2.8+ MB

# %%
#verifica se existe variáveis nulas 
dataset.isna().sum()
# Out:
# DT_MEDICAO_HORA           0
# PRECIPITACAO              0
# PRESSAO_ATMOSFERICA       0
# TEMPERATURA_DO_AR_C       0
# UMIDADE_RELATIVA_DO_AR    0
# VELOCIDADE_VENTO          0
# VL_MEDICAO                0
# dtype: int64

# %%
dataset.head(10)
# Out:
#         DT_MEDICAO_HORA  PRECIPITACAO  PRESSAO_ATMOSFERICA  \
# 1   2017-01-01 00:00:00           0.0               1009.5
# 2   2017-01-01 01:00:00           0.0               1009.6
# 3   2017-01-01 02:00:00           0.0               1009.2
# 4   2017-01-01 03:00:00           0.0               1008.4
# 5   2017-01-01 04:00:00           0.0               1008.1
# 6   2017-01-01 05:00:00           0.2               1007.5
# 7   2017-01-01 06:00:00           0.0               1007.3
# 8   2017-01-01 07:00:00           0.0               1007.3
# 9   2017-01-01 08:00:00           0.0               1007.7
# 10  2017-01-01 09:00:00           0.0               1008.5
#
#     TEMPERATURA_DO_AR_C  UMIDADE_RELATIVA_DO_AR  VELOCIDADE_VENTO   VL_MEDICAO
# 1                  25.9                    75.0               1.3  5016.845991
# 2                  25.7                    76.0               0.9  4998.296902
# 3                  25.6                    76.0               1.1  5013.330096
# 4                  25.9                    77.0               1.7  4972.739746
# 5                  23.7                    85.0               1.7  4921.942265
# 6                  23.7                    87.0               0.4  4838.136258
# 7                  24.2                    88.0               0.5  4833.215005
# 8                  24.2                    87.0               0.7  4795.247653
# 9                  24.7                    85.0               1.0  4763.098501
# 10                 25.1                    83.0               1.2  4715.598748

# %%
#tratando o dataframe
df = pd.DataFrame()
df['VL_MEDICAO']=dataset['VL_MEDICAO']
                                
#transformação da série => janela deslizande com 1 passo de tempo
n_time_steps=2
#transformação da série => janela deslizande com 1 passo de tempo
for n_step in range(1,n_time_steps+1,1):
 df['vl-'+str(n_step)]=dataset['VL_MEDICAO'].shift(n_step)  

#n=1
#df['vl-n']=dataset['VL_MEDICAO'].shift(n)
df['tp-n']=dataset['TEMPERATURA_DO_AR_C']
df['pr-n']=dataset['PRESSAO_ATMOSFERICA']
df['vv-n']=dataset['VELOCIDADE_VENTO']
df['ur-n']=dataset['UMIDADE_RELATIVA_DO_AR']
df['ch-n']=dataset['PRECIPITACAO']

df.dropna(inplace=True)
df.head(15)
# Out:
#      VL_MEDICAO         vl-1         vl-2  tp-n    pr-n  vv-n  ur-n  ch-n
# 3   5013.330096  4998.296902  5016.845991  25.6  1009.2   1.1  76.0   0.0
# 4   4972.739746  5013.330096  4998.296902  25.9  1008.4   1.7  77.0   0.0
# 5   4921.942265  4972.739746  5013.330096  23.7  1008.1   1.7  85.0   0.0
# 6   4838.136258  4921.942265  4972.739746  23.7  1007.5   0.4  87.0   0.2
# 7   4833.215005  4838.136258  4921.942265  24.2  1007.3   0.5  88.0   0.0
# 8   4795.247653  4833.215005  4838.136258  24.2  1007.3   0.7  87.0   0.0
# 9   4763.098501  4795.247653  4833.215005  24.7  1007.7   1.0  85.0   0.0
# 10  4715.598748  4763.098501  4795.247653  25.1  1008.5   1.2  83.0   0.0
# 11  4712.059896  4715.598748  4763.098501  26.2  1009.0   1.5  77.0   0.0
# 12  4657.193811  4712.059896  4715.598748  28.4  1009.5   1.6  67.0   0.0
# 13  4683.363206  4657.193811  4712.059896  28.7  1010.0   1.6  68.0   0.0
# 14  4699.865601  4683.363206  4657.193811  31.6  1010.2   1.5  57.0   0.0
# 15  4716.826297  4699.865601  4683.363206  31.2  1009.9   1.7  56.0   0.0
# 16  4715.140992  4716.826297  4699.865601  30.7  1009.5   1.4  56.0   0.0
# 17  4758.435488  4715.140992  4716.826297  31.8  1008.7   1.6  56.0   0.0

# %%
#Adição para calculo de Data
#df['DT_MEDICAO_HORA']=pd.to_datetime(dataset['DT_MEDICAO_HORA'])

# %%
#df['VL_MEDICAO_MA10'] = df['VL_MEDICAO'].rolling(10).mean().shift() #shift so the day we want to predict won't be used
#df['VL_MEDICAO_MA20'] = df['VL_MEDICAO'].rolling(20).mean().shift() #shift so the day we want to predict won't be used

# %%
#O gráfico abaixo mostra os valores reais em preto e os valores prditos em azul
#pyplot.figure(figsize=(10,7)) 
#pyplot.scatter(df['DT_MEDICAO_HORA'],df['VL_MEDICAO'], color = 'black')
#pyplot.scatter(df['DT_MEDICAO_HORA'],df['VL_MEDICAO_MA10'], color = 'green')
#pyplot.scatter(df['DT_MEDICAO_HORA'],df['VL_MEDICAO_MA20'], color = 'blue')
#pyplot.xlabel('n seq.')
#pyplot.ylabel('consumo l/h')
#pyplot.show()

# %%
#Cria os vetores de X e y para terinamento e teste
vl_medicoes = df.iloc[:,0].values

X = df.iloc[0:dataset.shape[0],1: 6 + n_time_steps]

#Definindo os datasets de treinamento e teste
#X_train, X_test, y_train, y_test = train_test_split(X, vl_medicoes, test_size=0.1, random_state= 1)

# %%
#Do total de 45239 linhas, foram separadas 75% para treinamento e 25% para teste
nlinhas = 33929 # 75% do dataset
X_train = df.iloc[0:nlinhas,1: 6 + n_time_steps]
X_test = df.iloc[nlinhas:X.shape[0],1:6 + n_time_steps]

y_train = df.iloc[0:nlinhas,0].values
y_test = df.iloc[nlinhas:X.shape[0],0].values

# %%
#!pip install tensorflow

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow import data
from keras.wrappers.scikit_learn import KerasRegressor
import time

# %%
train_feature = np.array(X_train).reshape((X_train.shape[0], 1, X_train.shape[1])) # dados de entrada de treinamento.
train_label = np.array(y_train).reshape((y_train.shape[0], 1, 1)) # dado de saída esperados no treinamento.

N_Nos_Layer1=32 #Número de neurônios do layer 1   # 64
N_Nos_Layer2=64 # Número de neurônios do layer 2  # 128
N_Nos_Layer3=72 # Númer ode neurônios do layer 3

# Armazena a hora de início da execução do Treinamento
Hora_Inicio = time.time()
# Resultados para o batch size encontrados, para 100 epocas, de acordo com a variação do batch size = desta forma o batch size ideal selecionado foi o 4096, considerando que a partir desse ponto o ganho é reduzido drasticamente.
# 128 = 99s   1024 = 20s   2048 = 13s  4096 = 10s 8192 = 9.53s
batch_size = 4096
train_data = data.Dataset.from_tensor_slices((train_feature, train_label))
train_data = train_data.repeat().batch(batch_size, drop_remainder=True)
EPOCAS = 200

model = keras.Sequential()
model.add(layers.LSTM(N_Nos_Layer1, batch_input_shape=(batch_size, train_feature.shape[1], train_feature.shape[2]),  return_sequences=True, activation='relu'))  
model.add(layers.LSTM(N_Nos_Layer2, batch_input_shape=(N_Nos_Layer1, train_feature.shape[1], train_feature.shape[2]), return_sequences=True, activation='relu'))  
#model.add(layers.LSTM(32, batch_input_shape=(N_Nos_Layer2, train_feature.shape[1], train_feature.shape[2]), return_sequences=True, activation='relu'))  
model.add(layers.Dense(32, activation="relu"))
model.add(layers.Dense(32, activation="relu")) #16
model.add(layers.Dense(1))
#model.add(layers.Activation('sigmoid'))

model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['mape'])

model.summary()

#history = model.fit(train_feature, train_label, epochs=EPOCAS,shuffle=True,batch_size=batch_size, verbose=2)
steps_per_epoch = len(train_feature) // batch_size 
history = model.fit(train_data, epochs=EPOCAS, steps_per_epoch = steps_per_epoch) 
# Armazena a hora fim da execução do Treinamento
Hora_Fim = time.time()

#Calcula o tempo de duração da execução do treinamento
Duracao = Hora_Fim - Hora_Inicio

print("Duracao =",Duracao)
#model.add(layers.LSTM(N_Nos_Layer1,input_shape=(1,1)))
  #model.add(layers.LSTM(N_Nos_Layer1,input_shape=(5,1), return_sequences=True))
#  model.add(layers.LSTM(N_Nos_Layer2,input_shape=(N_Nos_Layer1,5)))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (4096, 1, 32)             5120
#
#  lstm_1 (LSTM)               (4096, 1, 64)             24832
#
#  dense (Dense)               (4096, 1, 32)             2080
#
#  dense_1 (Dense)             (4096, 1, 32)             1056
#
#  dense_2 (Dense)             (4096, 1, 1)              33
#
# =================================================================
# Total params: 33,121
# Trainable params: 33,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 8/8 [==============================] - 2s 31ms/step - loss: 99.6708 - mape: 99.6708
# Epoch 2/200
# 8/8 [==============================] - 0s 31ms/step - loss: 98.7518 - mape: 98.7518
# Epoch 3/200
# 8/8 [==============================] - 0s 34ms/step - loss: 97.6683 - mape: 97.6683
# Epoch 4/200
# 8/8 [==============================] - 0s 31ms/step - loss: 95.9409 - mape: 95.9409
# Epoch 5/200
# 8/8 [==============================] - 0s 30ms/step - loss: 92.9309 - mape: 92.9309
# Epoch 6/200
# 8/8 [==============================] - 0s 29ms/step - loss: 84.4738 - mape: 84.4738
# Epoch 7/200
# 8/8 [==============================] - 0s 30ms/step - loss: 66.2891 - mape: 66.2891
# Epoch 8/200
# 8/8 [==============================] - 0s 27ms/step - loss: 37.4830 - mape: 37.4830
# Epoch 9/200
# 8/8 [==============================] - 0s 30ms/step - loss: 10.4966 - mape: 10.4966
# Epoch 10/200
# 8/8 [==============================] - 0s 30ms/step - loss: 7.5004 - mape: 7.5004
# Epoch 11/200
# 8/8 [==============================] - 0s 31ms/step - loss: 4.5392 - mape: 4.5392
# Epoch 12/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.7108 - mape: 2.7108
# Epoch 13/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.8158 - mape: 2.8158
# Epoch 14/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.8310 - mape: 2.8310
# Epoch 15/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.7382 - mape: 2.7382
# Epoch 16/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.7096 - mape: 2.7096
# Epoch 17/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.7045 - mape: 2.7045
# Epoch 18/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.7317 - mape: 2.7317
# Epoch 19/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.7190 - mape: 2.7190
# Epoch 20/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6874 - mape: 2.6874
# Epoch 21/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.7100 - mape: 2.7100
# Epoch 22/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.7043 - mape: 2.7043
# Epoch 23/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.7073 - mape: 2.7073
# Epoch 24/200
# 8/8 [==============================] - 0s 39ms/step - loss: 3.0808 - mape: 3.0808
# Epoch 25/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6294 - mape: 2.6294
# Epoch 26/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.7071 - mape: 2.7071
# Epoch 27/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6895 - mape: 2.6895
# Epoch 28/200
# 8/8 [==============================] - 0s 38ms/step - loss: 3.2159 - mape: 3.2159
# Epoch 29/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6900 - mape: 2.6900
# Epoch 30/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.7854 - mape: 2.7854
# Epoch 31/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.8087 - mape: 2.8087
# Epoch 32/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.7141 - mape: 2.7141
# Epoch 33/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6901 - mape: 2.6901
# Epoch 34/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6771 - mape: 2.6771
# Epoch 35/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6269 - mape: 2.6269
# Epoch 36/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6309 - mape: 2.6309
# Epoch 37/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.6167 - mape: 2.6167
# Epoch 38/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6361 - mape: 2.6361
# Epoch 39/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6032 - mape: 2.6032
# Epoch 40/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.5893 - mape: 2.5893
# Epoch 41/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5625 - mape: 2.5625
# Epoch 42/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.5994 - mape: 2.5994
# Epoch 43/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5966 - mape: 2.5966
# Epoch 44/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5969 - mape: 2.5969
# Epoch 45/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6023 - mape: 2.6023
# Epoch 46/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5559 - mape: 2.5559
# Epoch 47/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5813 - mape: 2.5813
# Epoch 48/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6069 - mape: 2.6069
# Epoch 49/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5951 - mape: 2.5951
# Epoch 50/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5831 - mape: 2.5831
# Epoch 51/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.5568 - mape: 2.5568
# Epoch 52/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6156 - mape: 2.6156
# Epoch 53/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5720 - mape: 2.5720
# Epoch 54/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5794 - mape: 2.5794
# Epoch 55/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5829 - mape: 2.5829
# Epoch 56/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5786 - mape: 2.5786
# Epoch 57/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.5848 - mape: 2.5848
# Epoch 58/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.5871 - mape: 2.5871
# Epoch 59/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.5992 - mape: 2.5992
# Epoch 60/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6050 - mape: 2.6050
# Epoch 61/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6133 - mape: 2.6133
# Epoch 62/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.6179 - mape: 2.6179
# Epoch 63/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6122 - mape: 2.6122
# Epoch 64/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5745 - mape: 2.5745
# Epoch 65/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.5897 - mape: 2.5897
# Epoch 66/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5824 - mape: 2.5824
# Epoch 67/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5882 - mape: 2.5882
# Epoch 68/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5583 - mape: 2.5583
# Epoch 69/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5600 - mape: 2.5600
# Epoch 70/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5190 - mape: 2.5190
# Epoch 71/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5601 - mape: 2.5601
# Epoch 72/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5610 - mape: 2.5610
# Epoch 73/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5581 - mape: 2.5581
# Epoch 74/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5654 - mape: 2.5654
# Epoch 75/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5461 - mape: 2.5461
# Epoch 76/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5364 - mape: 2.5364
# Epoch 77/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5758 - mape: 2.5758
# Epoch 78/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.5706 - mape: 2.5706
# Epoch 79/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5501 - mape: 2.5501
# Epoch 80/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5155 - mape: 2.5155
# Epoch 81/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.5729 - mape: 2.5729
# Epoch 82/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5582 - mape: 2.5582
# Epoch 83/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5538 - mape: 2.5538
# Epoch 84/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5631 - mape: 2.5631
# Epoch 85/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5530 - mape: 2.5530
# Epoch 86/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5606 - mape: 2.5606
# Epoch 87/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5733 - mape: 2.5733
# Epoch 88/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5694 - mape: 2.5694
# Epoch 89/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5789 - mape: 2.5789
# Epoch 90/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5780 - mape: 2.5780
# Epoch 91/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5884 - mape: 2.5884
# Epoch 92/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5757 - mape: 2.5757
# Epoch 93/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5522 - mape: 2.5522
# Epoch 94/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5617 - mape: 2.5617
# Epoch 95/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.5454 - mape: 2.5454
# Epoch 96/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5619 - mape: 2.5619
# Epoch 97/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5536 - mape: 2.5536
# Epoch 98/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5269 - mape: 2.5269
# Epoch 99/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.4875 - mape: 2.4875
# Epoch 100/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5420 - mape: 2.5420
# Epoch 101/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5392 - mape: 2.5392
# Epoch 102/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5333 - mape: 2.5333
# Epoch 103/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5524 - mape: 2.5524
# Epoch 104/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5434 - mape: 2.5434
# Epoch 105/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5113 - mape: 2.5113
# Epoch 106/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5550 - mape: 2.5550
# Epoch 107/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5612 - mape: 2.5612
# Epoch 108/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5495 - mape: 2.5495
# Epoch 109/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5285 - mape: 2.5285
# Epoch 110/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.5489 - mape: 2.5489
# Epoch 111/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5510 - mape: 2.5510
# Epoch 112/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5485 - mape: 2.5485
# Epoch 113/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5485 - mape: 2.5485
# Epoch 114/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5491 - mape: 2.5491
# Epoch 115/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5467 - mape: 2.5467
# Epoch 116/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5775 - mape: 2.5775
# Epoch 117/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5669 - mape: 2.5669
# Epoch 118/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5798 - mape: 2.5798
# Epoch 119/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5717 - mape: 2.5717
# Epoch 120/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5929 - mape: 2.5929
# Epoch 121/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5711 - mape: 2.5711
# Epoch 122/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5606 - mape: 2.5606
# Epoch 123/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5602 - mape: 2.5602
# Epoch 124/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5507 - mape: 2.5507
# Epoch 125/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5564 - mape: 2.5564
# Epoch 126/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5681 - mape: 2.5681
# Epoch 127/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5284 - mape: 2.5284
# Epoch 128/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5209 - mape: 2.5209
# Epoch 129/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5107 - mape: 2.5107
# Epoch 130/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5396 - mape: 2.5396
# Epoch 131/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5408 - mape: 2.5408
# Epoch 132/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5422 - mape: 2.5422
# Epoch 133/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5385 - mape: 2.5385
# Epoch 134/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5088 - mape: 2.5088
# Epoch 135/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5384 - mape: 2.5384
# Epoch 136/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5581 - mape: 2.5581
# Epoch 137/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5392 - mape: 2.5392
# Epoch 138/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5349 - mape: 2.5349
# Epoch 139/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5221 - mape: 2.5221
# Epoch 140/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5443 - mape: 2.5443
# Epoch 141/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5395 - mape: 2.5395
# Epoch 142/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5403 - mape: 2.5403
# Epoch 143/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5420 - mape: 2.5420
# Epoch 144/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5371 - mape: 2.5371
# Epoch 145/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5659 - mape: 2.5659
# Epoch 146/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5583 - mape: 2.5583
# Epoch 147/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5637 - mape: 2.5637
# Epoch 148/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5577 - mape: 2.5577
# Epoch 149/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5818 - mape: 2.5818
# Epoch 150/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5616 - mape: 2.5616
# Epoch 151/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5586 - mape: 2.5586
# Epoch 152/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5480 - mape: 2.5480
# Epoch 153/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.5472 - mape: 2.5472
# Epoch 154/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5404 - mape: 2.5404
# Epoch 155/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5684 - mape: 2.5684
# Epoch 156/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5281 - mape: 2.5281
# Epoch 157/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.5110 - mape: 2.5110
# Epoch 158/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.5003 - mape: 2.5003
# Epoch 159/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.5296 - mape: 2.5296
# Epoch 160/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5421 - mape: 2.5421
# Epoch 161/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5574 - mape: 2.5574
# Epoch 162/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.5693 - mape: 2.5693
# Epoch 163/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5099 - mape: 2.5099
# Epoch 164/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.5536 - mape: 2.5536
# Epoch 165/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5523 - mape: 2.5523
# Epoch 166/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5501 - mape: 2.5501
# Epoch 167/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5248 - mape: 2.5248
# Epoch 168/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5049 - mape: 2.5049
# Epoch 169/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5513 - mape: 2.5513
# Epoch 170/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5229 - mape: 2.5229
# Epoch 171/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5313 - mape: 2.5313
# Epoch 172/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5262 - mape: 2.5262
# Epoch 173/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5440 - mape: 2.5440
# Epoch 174/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5364 - mape: 2.5364
# Epoch 175/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5471 - mape: 2.5471
# Epoch 176/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5541 - mape: 2.5541
# Epoch 177/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5565 - mape: 2.5565
# Epoch 178/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5546 - mape: 2.5546
# Epoch 179/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5562 - mape: 2.5562
# Epoch 180/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5558 - mape: 2.5558
# Epoch 181/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5214 - mape: 2.5214
# Epoch 182/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5425 - mape: 2.5425
# Epoch 183/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5278 - mape: 2.5278
# Epoch 184/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5428 - mape: 2.5428
# Epoch 185/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5143 - mape: 2.5143
# Epoch 186/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5056 - mape: 2.5056
# Epoch 187/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.4762 - mape: 2.4762
# Epoch 188/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5103 - mape: 2.5103
# Epoch 189/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.5188 - mape: 2.5188
# Epoch 190/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5177 - mape: 2.5177
# Epoch 191/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5179 - mape: 2.5179
# Epoch 192/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.4959 - mape: 2.4959
# Epoch 193/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.4948 - mape: 2.4948
# Epoch 194/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5327 - mape: 2.5327
# Epoch 195/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5230 - mape: 2.5230
# Epoch 196/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.5126 - mape: 2.5126
# Epoch 197/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.4761 - mape: 2.4761
# Epoch 198/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5398 - mape: 2.5398
# Epoch 199/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5151 - mape: 2.5151
# Epoch 200/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5203 - mape: 2.5203
# Duracao = 54.85927939414978

# %%
val_feature = np.array(X_test).reshape((X_test.shape[0], 1, X_test.shape[1]))
val_label = np.array(y_test).reshape((y_test.shape[0], 1, 1))


test_data = data.Dataset.from_tensor_slices((val_feature, val_label))
test_data = test_data.repeat().batch(batch_size, drop_remainder=True)

predict = model.predict(test_data, steps=1)
#predict = model.predict(train_data, steps=1)

val_label=val_label[0:len(predict)]

predict = np.array(predict).reshape(4096,1)
val_label = np.array(val_label).reshape(4096,1)

#Calcular o MAPE (Erro médio percentual absoluto)
MAPE = ((np.mean(np.abs(val_label -predict) / (val_label)))) * 100
print("MAPE=", MAPE)
# Out:
# MAPE= 1.781435952046405

# %%
#O gráfico abaixo mostra os valores reais em preto e os valores prditos em azul
npredicts=1000
pyplot.figure(figsize=(10,7)) 
pyplot.scatter(np.arange(0,val_label.shape[0],1)[0:npredicts],np.array(val_label)[0:npredicts], color = 'black')
pyplot.plot(np.arange(0,val_label.shape[0],1)[0:npredicts], np.array(predict)[0:npredicts], color = 'blue', linewidth=2)
pyplot.xlabel('n seq.')
pyplot.ylabel('consumo l/h')
pyplot.show()
