# %%
import pandas as pd
import numpy as np
import random as rd
import seaborn as sbs
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from matplotlib import pyplot
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow
from tensorflow import data

# %%
file_data = 'DS_Agua_2017_2022.csv'
path_name='data/'
arquivo = f'{path_name}{file_data}'

# %%
dataset = pd.read_csv(arquivo, sep =';', encoding = 'latin1', decimal='.')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45240 entries, 1 to 45240
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DT_MEDICAO_HORA         45240 non-null  object
#  1   PRECIPITACAO            45240 non-null  float64
#  2   PRESSAO_ATMOSFERICA     45240 non-null  float64
#  3   TEMPERATURA_DO_AR_C     45240 non-null  float64
#  4   UMIDADE_RELATIVA_DO_AR  45240 non-null  float64
#  5   VELOCIDADE_VENTO        45240 non-null  float64
#  6   VL_MEDICAO              45240 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 2.8+ MB

# %%
#verifica se existe variáveis nulas 
dataset.isna().sum()
# Out:
# DT_MEDICAO_HORA           0
# PRECIPITACAO              0
# PRESSAO_ATMOSFERICA       0
# TEMPERATURA_DO_AR_C       0
# UMIDADE_RELATIVA_DO_AR    0
# VELOCIDADE_VENTO          0
# VL_MEDICAO                0
# dtype: int64

# %%
dataset.head(10)
# Out:
#         DT_MEDICAO_HORA  PRECIPITACAO  PRESSAO_ATMOSFERICA  \
# 1   2017-01-01 00:00:00           0.0               1009.5
# 2   2017-01-01 01:00:00           0.0               1009.6
# 3   2017-01-01 02:00:00           0.0               1009.2
# 4   2017-01-01 03:00:00           0.0               1008.4
# 5   2017-01-01 04:00:00           0.0               1008.1
# 6   2017-01-01 05:00:00           0.2               1007.5
# 7   2017-01-01 06:00:00           0.0               1007.3
# 8   2017-01-01 07:00:00           0.0               1007.3
# 9   2017-01-01 08:00:00           0.0               1007.7
# 10  2017-01-01 09:00:00           0.0               1008.5
#
#     TEMPERATURA_DO_AR_C  UMIDADE_RELATIVA_DO_AR  VELOCIDADE_VENTO   VL_MEDICAO
# 1                  25.9                    75.0               1.3  5016.845991
# 2                  25.7                    76.0               0.9  4998.296902
# 3                  25.6                    76.0               1.1  5013.330096
# 4                  25.9                    77.0               1.7  4972.739746
# 5                  23.7                    85.0               1.7  4921.942265
# 6                  23.7                    87.0               0.4  4838.136258
# 7                  24.2                    88.0               0.5  4833.215005
# 8                  24.2                    87.0               0.7  4795.247653
# 9                  24.7                    85.0               1.0  4763.098501
# 10                 25.1                    83.0               1.2  4715.598748

# %%
#tratando o dataframe
n_time_steps=3
df = pd.DataFrame()
df['VL_MEDICAO']=dataset['VL_MEDICAO']

#transformação da série => janela deslizande com 1 passo de tempo
for n_step in range(1,n_time_steps+1,1):
 df['vl-'+str(n_step)]=dataset['VL_MEDICAO'].shift(n_step)  
 
df['tp-n']=dataset['TEMPERATURA_DO_AR_C']
df['pr-n']=dataset['PRESSAO_ATMOSFERICA']
df['vv-n']=dataset['VELOCIDADE_VENTO']
df['ur-n']=dataset['UMIDADE_RELATIVA_DO_AR']
df['ch-n']=dataset['PRECIPITACAO']

df.dropna(inplace=True)
df.head(15)
# Out:
#      VL_MEDICAO         vl-1         vl-2         vl-3  tp-n    pr-n  vv-n  \
# 4   4972.739746  5013.330096  4998.296902  5016.845991  25.9  1008.4   1.7
# 5   4921.942265  4972.739746  5013.330096  4998.296902  23.7  1008.1   1.7
# 6   4838.136258  4921.942265  4972.739746  5013.330096  23.7  1007.5   0.4
# 7   4833.215005  4838.136258  4921.942265  4972.739746  24.2  1007.3   0.5
# 8   4795.247653  4833.215005  4838.136258  4921.942265  24.2  1007.3   0.7
# 9   4763.098501  4795.247653  4833.215005  4838.136258  24.7  1007.7   1.0
# 10  4715.598748  4763.098501  4795.247653  4833.215005  25.1  1008.5   1.2
# 11  4712.059896  4715.598748  4763.098501  4795.247653  26.2  1009.0   1.5
# 12  4657.193811  4712.059896  4715.598748  4763.098501  28.4  1009.5   1.6
# 13  4683.363206  4657.193811  4712.059896  4715.598748  28.7  1010.0   1.6
# 14  4699.865601  4683.363206  4657.193811  4712.059896  31.6  1010.2   1.5
# 15  4716.826297  4699.865601  4683.363206  4657.193811  31.2  1009.9   1.7
# 16  4715.140992  4716.826297  4699.865601  4683.363206  30.7  1009.5   1.4
# 17  4758.435488  4715.140992  4716.826297  4699.865601  31.8  1008.7   1.6
# 18  4721.544583  4758.435488  4715.140992  4716.826297  31.1  1008.0   1.8
#
#     ur-n  ch-n
# 4   77.0   0.0
# 5   85.0   0.0
# 6   87.0   0.2
# 7   88.0   0.0
# 8   87.0   0.0
# 9   85.0   0.0
# 10  83.0   0.0
# 11  77.0   0.0
# 12  67.0   0.0
# 13  68.0   0.0
# 14  57.0   0.0
# 15  56.0   0.0
# 16  56.0   0.0
# 17  56.0   0.0
# 18  58.0   0.0

# %%
#Do total de 45239 linhas, foram separadas 75% para treinamento e 25% para teste
nlinhas = int(np.round(dataset.shape[0] * 0.75)) # 

#nlinhas = 33929 # 75% do dataset
X_train = df.iloc[0:nlinhas,1: 6 + n_time_steps]
X_test = df.iloc[nlinhas:dataset.shape[0],1: 6 + n_time_steps]

y_train = df.iloc[0:nlinhas,0].values
y_test = df.iloc[nlinhas:dataset.shape[0],0].values

# %%
def treinar_LSTM(X_train, y_train, N_Nos_Layer1, N_Nos_Layer2,N_Nos_Layer3, EPOCAS , batch_size = 4096):
  train_feature = np.array(X_train).reshape((X_train.shape[0], 1, X_train.shape[1]))
  train_label = np.array(y_train).reshape((y_train.shape[0], 1, 1))

  # Armazena a hora de início da execução do Treinamento
  # batch_size = 4096 # Tamanho de cada lote de processamento usando para o modelo abstrair os padrões
  # EPOCAS é o número de vezes que o conjunto de lotes irá ser processado pelo modelo na fase de treinamento.

  train_data = data.Dataset.from_tensor_slices((train_feature, train_label))
  train_data = train_data.repeat().batch(batch_size, drop_remainder=True)

  
  model = keras.Sequential()
  model.add(layers.LSTM(N_Nos_Layer1, batch_input_shape=(batch_size, train_feature.shape[1], train_feature.shape[2]),  return_sequences=True, activation='relu'))  
  model.add(layers.LSTM(N_Nos_Layer2, batch_input_shape=(N_Nos_Layer1, train_feature.shape[1], train_feature.shape[2]), return_sequences=True, activation='relu'))  
  model.add(layers.Dense(N_Nos_Layer3, activation="relu"))
  model.add(layers.Dense(1))

  #mean_squared_error
  model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['mape'])
  model.summary()
  steps_per_epoch = len(train_feature) // batch_size 
  history = model.fit(train_data, epochs=EPOCAS, steps_per_epoch = steps_per_epoch) 

  val_feature = np.array(X_train).reshape((X_train.shape[0], 1, X_train.shape[1]))
  val_label = np.array(y_train).reshape((y_train.shape[0], 1, 1))


  train_data = data.Dataset.from_tensor_slices((val_feature, val_label))
  train_data = train_data.repeat().batch(batch_size, drop_remainder=True)

  predict = model.predict(train_data, steps=1)

  val_label=val_label[0:len(predict)]

  predict = np.array(predict).reshape(batch_size,1)
  val_label = np.array(val_label).reshape(batch_size,1)

  val_label=val_label[0:len(predict)]

  #Validação dos resultados

  #Calcular o MAPE (Erro médio percentual absoluto)
  MAPE = ((np.mean(np.abs(val_label -predict) / (val_label)))) * 100 
  
  return MAPE, model

# %%
def previsao_LSTM(X_test, y_test, model, batch_size):
  val_feature = np.array(X_test).reshape((X_test.shape[0], 1, X_test.shape[1]))
  val_label = np.array(y_test).reshape((y_test.shape[0], 1, 1))


  test_data = data.Dataset.from_tensor_slices((val_feature, val_label))
  test_data = test_data.repeat().batch(batch_size, drop_remainder=True)

  predict = model.predict(test_data, steps=1)
  #predict = model.predict(train_data, steps=1)

  val_label=val_label[0:len(predict)]

  predict = np.array(predict).reshape(batch_size,1)
  val_label = np.array(val_label).reshape(batch_size,1)

  #Calcular o MAPE (Erro médio percentual absoluto)
  MAPE = ((np.mean(np.abs(val_label -predict) / (val_label)))) * 100
  
  return MAPE, predict, val_label

# %%
class BestModel:
  #Classe para armazenar os melhores hiperparâmetros
  def __init__(self,  N_Nos_Layer1, N_Nos_Layer2, N_Nos_Layer3, MAPE, model = 0):
    self.N_Nos_Layer1 = N_Nos_Layer1
    self.N_Nos_Layer2 = N_Nos_Layer2
    self.N_Nos_Layer3 = N_Nos_Layer3
    self.MAPE = MAPE
    self.model = model
  
  def setIndex(self, N_Nos_Layer1, N_Nos_Layer2, N_Nos_Layer3, MAPE, model):
    self.N_Nos_Layer1 = N_Nos_Layer1
    self.N_Nos_Layer2 = N_Nos_Layer2
    self.N_Nos_Layer3 = N_Nos_Layer3
    self.MAPE = MAPE
    self.model = model
        
  def show(self):
    print(" LSTM (", self.N_Nos_Layer1, ",", self.N_Nos_Layer2, ",", self.N_Nos_Layer3, ") MAPE ", self.MAPE)

        
# Efetuar o processo de Calibração da LSTM, variando os hiperparâmetros
#N_Nos_Layer1 = 5
#N_Nos_Layer2 = 15
EPOCAS = 200
batch_size = 4096
MAPE = 100
bestModel = BestModel(N_Nos_Layer1, N_Nos_Layer2, N_Nos_Layer3, MAPE)
arquivo='Result_LSTM_Model.csv'

#n_valores_passado = 10
##criar_arquivo_resultado(arquivo)
#Laço para variação da Camada Oculta 1
for N_Nos_Layer1 in range (32,6,-8):
  #Laço para variação da Camada Oculta 2
  for N_Nos_Layer2 in range (32,6,-8):
    for N_Nos_Layer3 in range (32,6,-8):
      #Chama a função de treinamento da LSTM com os hiperparâmetros selecionados para cada iteração
      MAPE, model = treinar_LSTM(X_train, y_train, N_Nos_Layer1, N_Nos_Layer2, N_Nos_Layer3, EPOCAS, batch_size)
      #armazena o melhor modelo, com o menor MAPE
      if(bestModel.MAPE > MAPE):
        bestModel.setIndex(N_Nos_Layer1, N_Nos_Layer2, N_Nos_Layer3, MAPE, model)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (4096, 1, 32)             5248
#
#  lstm_1 (LSTM)               (4096, 1, 32)             8320
#
#  dense (Dense)               (4096, 1, 32)             1056
#
#  dense_1 (Dense)             (4096, 1, 1)              33
#
# =================================================================
# Total params: 14,657
# Trainable params: 14,657
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 8/8 [==============================] - 2s 36ms/step - loss: 100.8391 - mape: 100.8391
# Epoch 2/200
# 8/8 [==============================] - 0s 43ms/step - loss: 98.6134 - mape: 98.6134
# Epoch 3/200
# 8/8 [==============================] - 0s 38ms/step - loss: 96.7465 - mape: 96.7465
# Epoch 4/200
# 8/8 [==============================] - 0s 40ms/step - loss: 94.5604 - mape: 94.5604
# Epoch 5/200
# 8/8 [==============================] - 0s 50ms/step - loss: 92.0115 - mape: 92.0115
# Epoch 6/200
# 8/8 [==============================] - 0s 49ms/step - loss: 88.8708 - mape: 88.8708
# Epoch 7/200
# 8/8 [==============================] - 0s 51ms/step - loss: 84.8351 - mape: 84.8351
# Epoch 8/200
# 8/8 [==============================] - 0s 57ms/step - loss: 79.1100 - mape: 79.1100
# Epoch 9/200
# 8/8 [==============================] - 0s 52ms/step - loss: 71.0630 - mape: 71.0630
# Epoch 10/200
# 8/8 [==============================] - 0s 51ms/step - loss: 60.5294 - mape: 60.5294
# Epoch 11/200
# 8/8 [==============================] - 0s 46ms/step - loss: 46.5904 - mape: 46.5904
# Epoch 12/200
# 8/8 [==============================] - 0s 43ms/step - loss: 28.1047 - mape: 28.1047
# Epoch 13/200
# 8/8 [==============================] - 0s 49ms/step - loss: 7.5829 - mape: 7.5829
# Epoch 14/200
# 8/8 [==============================] - 0s 45ms/step - loss: 7.8889 - mape: 7.8889
# Epoch 15/200
# 8/8 [==============================] - 0s 49ms/step - loss: 3.5440 - mape: 3.5440
# Epoch 16/200
# 8/8 [==============================] - 0s 46ms/step - loss: 3.3215 - mape: 3.3215
# Epoch 17/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.9345 - mape: 2.9345
# Epoch 18/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.9589 - mape: 2.9589
# Epoch 19/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7407 - mape: 2.7407
# Epoch 20/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.7661 - mape: 2.7661
# Epoch 21/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6890 - mape: 2.6890
# Epoch 22/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.7194 - mape: 2.7194
# Epoch 23/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.7114 - mape: 2.7114
# Epoch 24/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.7090 - mape: 2.7090
# Epoch 25/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7009 - mape: 2.7009
# Epoch 26/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.7000 - mape: 2.7000
# Epoch 27/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6773 - mape: 2.6773
# Epoch 28/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.7126 - mape: 2.7126
# Epoch 29/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.7000 - mape: 2.7000
# Epoch 30/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.7218 - mape: 2.7218
# Epoch 31/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.7039 - mape: 2.7039
# Epoch 32/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.7240 - mape: 2.7240
# Epoch 33/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.7098 - mape: 2.7098
# Epoch 34/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.7079 - mape: 2.7079
# Epoch 35/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6734 - mape: 2.6734
# Epoch 36/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6816 - mape: 2.6816
# Epoch 37/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6774 - mape: 2.6774
# Epoch 38/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6980 - mape: 2.6980
# Epoch 39/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6540 - mape: 2.6540
# Epoch 40/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6382 - mape: 2.6382
# Epoch 41/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6122 - mape: 2.6122
# Epoch 42/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6564 - mape: 2.6564
# Epoch 43/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6498 - mape: 2.6498
# Epoch 44/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6518 - mape: 2.6518
# Epoch 45/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6661 - mape: 2.6661
# Epoch 46/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6285 - mape: 2.6285
# Epoch 47/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6514 - mape: 2.6514
# Epoch 48/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6723 - mape: 2.6723
# Epoch 49/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6540 - mape: 2.6540
# Epoch 50/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6448 - mape: 2.6448
# Epoch 51/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6278 - mape: 2.6278
# Epoch 52/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6719 - mape: 2.6719
# Epoch 53/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6455 - mape: 2.6455
# Epoch 54/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6490 - mape: 2.6490
# Epoch 55/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6492 - mape: 2.6492
# Epoch 56/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6510 - mape: 2.6510
# Epoch 57/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6441 - mape: 2.6441
# Epoch 58/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6534 - mape: 2.6534
# Epoch 59/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.6648 - mape: 2.6648
# Epoch 60/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6592 - mape: 2.6592
# Epoch 61/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6692 - mape: 2.6692
# Epoch 62/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6674 - mape: 2.6674
# Epoch 63/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6616 - mape: 2.6616
# Epoch 64/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6267 - mape: 2.6267
# Epoch 65/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6408 - mape: 2.6408
# Epoch 66/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6326 - mape: 2.6326
# Epoch 67/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6452 - mape: 2.6452
# Epoch 68/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6151 - mape: 2.6151
# Epoch 69/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6139 - mape: 2.6139
# Epoch 70/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5639 - mape: 2.5639
# Epoch 71/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6097 - mape: 2.6097
# Epoch 72/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.6183 - mape: 2.6183
# Epoch 73/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6174 - mape: 2.6174
# Epoch 74/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6208 - mape: 2.6208
# Epoch 75/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6045 - mape: 2.6045
# Epoch 76/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6082 - mape: 2.6082
# Epoch 77/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6418 - mape: 2.6418
# Epoch 78/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6254 - mape: 2.6254
# Epoch 79/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6176 - mape: 2.6176
# Epoch 80/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.5907 - mape: 2.5907
# Epoch 81/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6466 - mape: 2.6466
# Epoch 82/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6210 - mape: 2.6210
# Epoch 83/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6239 - mape: 2.6239
# Epoch 84/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6280 - mape: 2.6280
# Epoch 85/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6234 - mape: 2.6234
# Epoch 86/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6238 - mape: 2.6238
# Epoch 87/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6346 - mape: 2.6346
# Epoch 88/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6404 - mape: 2.6404
# Epoch 89/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6401 - mape: 2.6401
# Epoch 90/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6430 - mape: 2.6430
# Epoch 91/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6535 - mape: 2.6535
# Epoch 92/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6426 - mape: 2.6426
# Epoch 93/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6132 - mape: 2.6132
# Epoch 94/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6249 - mape: 2.6249
# Epoch 95/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6117 - mape: 2.6117
# Epoch 96/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6272 - mape: 2.6272
# Epoch 97/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6194 - mape: 2.6194
# Epoch 98/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5882 - mape: 2.5882
# Epoch 99/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.5463 - mape: 2.5463
# Epoch 100/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6022 - mape: 2.6022
# Epoch 101/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6032 - mape: 2.6032
# Epoch 102/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5927 - mape: 2.5927
# Epoch 103/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6160 - mape: 2.6160
# Epoch 104/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6012 - mape: 2.6012
# Epoch 105/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.5833 - mape: 2.5833
# Epoch 106/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6267 - mape: 2.6267
# Epoch 107/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6214 - mape: 2.6214
# Epoch 108/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6020 - mape: 2.6020
# Epoch 109/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5867 - mape: 2.5867
# Epoch 110/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6211 - mape: 2.6211
# Epoch 111/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6139 - mape: 2.6139
# Epoch 112/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6131 - mape: 2.6131
# Epoch 113/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6163 - mape: 2.6163
# Epoch 114/200
# 8/8 [==============================] - 0s 63ms/step - loss: 2.6219 - mape: 2.6219
# Epoch 115/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6069 - mape: 2.6069
# Epoch 116/200
# 8/8 [==============================] - 0s 53ms/step - loss: 2.6325 - mape: 2.6325
# Epoch 117/200
# 8/8 [==============================] - 0s 53ms/step - loss: 2.6270 - mape: 2.6270
# Epoch 118/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6328 - mape: 2.6328
# Epoch 119/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6323 - mape: 2.6323
# Epoch 120/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6514 - mape: 2.6514
# Epoch 121/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6344 - mape: 2.6344
# Epoch 122/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6174 - mape: 2.6174
# Epoch 123/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6147 - mape: 2.6147
# Epoch 124/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6071 - mape: 2.6071
# Epoch 125/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6226 - mape: 2.6226
# Epoch 126/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6230 - mape: 2.6230
# Epoch 127/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.5929 - mape: 2.5929
# Epoch 128/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.5612 - mape: 2.5612
# Epoch 129/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5866 - mape: 2.5866
# Epoch 130/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.5972 - mape: 2.5972
# Epoch 131/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5995 - mape: 2.5995
# Epoch 132/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6137 - mape: 2.6137
# Epoch 133/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6060 - mape: 2.6060
# Epoch 134/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.5795 - mape: 2.5795
# Epoch 135/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6194 - mape: 2.6194
# Epoch 136/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6288 - mape: 2.6288
# Epoch 137/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6076 - mape: 2.6076
# Epoch 138/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.5978 - mape: 2.5978
# Epoch 139/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6079 - mape: 2.6079
# Epoch 140/200
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6226 - mape: 2.6226
# Epoch 141/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6210 - mape: 2.6210
# Epoch 142/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6208 - mape: 2.6208
# Epoch 143/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6259 - mape: 2.6259
# Epoch 144/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6170 - mape: 2.6170
# Epoch 145/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6428 - mape: 2.6428
# Epoch 146/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6320 - mape: 2.6320
# Epoch 147/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6455 - mape: 2.6455
# Epoch 148/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6390 - mape: 2.6390
# Epoch 149/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6619 - mape: 2.6619
# Epoch 150/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6416 - mape: 2.6416
# Epoch 151/200
# 8/8 [==============================] - 0s 28ms/step - loss: 2.6379 - mape: 2.6379
# Epoch 152/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6238 - mape: 2.6238
# Epoch 153/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6193 - mape: 2.6193
# Epoch 154/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6270 - mape: 2.6270
# Epoch 155/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6518 - mape: 2.6518
# Epoch 156/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6044 - mape: 2.6044
# Epoch 157/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.5953 - mape: 2.5953
# Epoch 158/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.5780 - mape: 2.5780
# Epoch 159/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.6126 - mape: 2.6126
# Epoch 160/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.6160 - mape: 2.6160
# Epoch 161/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6168 - mape: 2.6168
# Epoch 162/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6251 - mape: 2.6251
# Epoch 163/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.5982 - mape: 2.5982
# Epoch 164/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6216 - mape: 2.6216
# Epoch 165/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6387 - mape: 2.6387
# Epoch 166/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6207 - mape: 2.6207
# Epoch 167/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6204 - mape: 2.6204
# Epoch 168/200
# 8/8 [==============================] - 0s 27ms/step - loss: 2.5999 - mape: 2.5999
# Epoch 169/200
# 8/8 [==============================] - 0s 30ms/step - loss: 2.6372 - mape: 2.6372
# Epoch 170/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6315 - mape: 2.6315
# Epoch 171/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6269 - mape: 2.6269
# Epoch 172/200
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6292 - mape: 2.6292
# Epoch 173/200
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6183 - mape: 2.6183
# Epoch 174/200
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6486 - mape: 2.6486
# Epoch 175/200
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6294 - mape: 2.6294
# Epoch 176/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6456 - mape: 2.6456
# Epoch 177/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.6418 - mape: 2.6418
# Epoch 178/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6544 - mape: 2.6544
# Epoch 179/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6416 - mape: 2.6416
# Epoch 180/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6373 - mape: 2.6373
# Epoch 181/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6148 - mape: 2.6148
# Epoch 182/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6215 - mape: 2.6215
# Epoch 183/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6108 - mape: 2.6108
# Epoch 184/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6430 - mape: 2.6430
# Epoch 185/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6038 - mape: 2.6038
# Epoch 186/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5833 - mape: 2.5833
# Epoch 187/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.5599 - mape: 2.5599
# Epoch 188/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6068 - mape: 2.6068
# Epoch 189/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5994 - mape: 2.5994
# Epoch 190/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.5976 - mape: 2.5976
# Epoch 191/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6142 - mape: 2.6142
# Epoch 192/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5790 - mape: 2.5790
# Epoch 193/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6001 - mape: 2.6001
# Epoch 194/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6205 - mape: 2.6205
# Epoch 195/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6110 - mape: 2.6110
# Epoch 196/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6011 - mape: 2.6011
# Epoch 197/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.5825 - mape: 2.5825
# Epoch 198/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6308 - mape: 2.6308
# Epoch 199/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6124 - mape: 2.6124
# Epoch 200/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6161 - mape: 2.6161
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (4096, 1, 32)             5248
#
#  lstm_3 (LSTM)               (4096, 1, 32)             8320
#
#  dense_2 (Dense)             (4096, 1, 24)             792
#
#  dense_3 (Dense)             (4096, 1, 1)              25
#
# =================================================================
# Total params: 14,385
# Trainable params: 14,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 8/8 [==============================] - 4s 47ms/step - loss: 98.6084 - mape: 98.6084
# Epoch 2/200
# 8/8 [==============================] - 0s 47ms/step - loss: 96.9829 - mape: 96.9829
# Epoch 3/200
# 8/8 [==============================] - 0s 44ms/step - loss: 94.8393 - mape: 94.8393
# Epoch 4/200
# 8/8 [==============================] - 0s 46ms/step - loss: 92.7909 - mape: 92.7909
# Epoch 5/200
# 8/8 [==============================] - 0s 44ms/step - loss: 90.1851 - mape: 90.1851
# Epoch 6/200
# 8/8 [==============================] - 0s 50ms/step - loss: 86.8224 - mape: 86.8224
# Epoch 7/200
# 8/8 [==============================] - 0s 45ms/step - loss: 82.3848 - mape: 82.3848
# Epoch 8/200
# 8/8 [==============================] - 0s 46ms/step - loss: 76.3360 - mape: 76.3360
# Epoch 9/200
# 8/8 [==============================] - 0s 49ms/step - loss: 67.3981 - mape: 67.3981
# Epoch 10/200
# 8/8 [==============================] - 0s 40ms/step - loss: 54.9150 - mape: 54.9150
# Epoch 11/200
# 8/8 [==============================] - 0s 42ms/step - loss: 37.9008 - mape: 37.9008
# Epoch 12/200
# 8/8 [==============================] - 0s 48ms/step - loss: 15.0350 - mape: 15.0350
# Epoch 13/200
# 8/8 [==============================] - 0s 44ms/step - loss: 8.3088 - mape: 8.3088
# Epoch 14/200
# 8/8 [==============================] - 0s 50ms/step - loss: 4.9344 - mape: 4.9344
# Epoch 15/200
# 8/8 [==============================] - 0s 45ms/step - loss: 5.1132 - mape: 5.1132
# Epoch 16/200
# 8/8 [==============================] - 0s 50ms/step - loss: 3.7449 - mape: 3.7449
# Epoch 17/200
# 8/8 [==============================] - 0s 54ms/step - loss: 2.9813 - mape: 2.9813
# Epoch 18/200
# 8/8 [==============================] - 0s 48ms/step - loss: 3.2081 - mape: 3.2081
# Epoch 19/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.9752 - mape: 2.9752
# Epoch 20/200
# 8/8 [==============================] - 0s 47ms/step - loss: 3.0275 - mape: 3.0275
# Epoch 21/200
# 8/8 [==============================] - 0s 51ms/step - loss: 2.9536 - mape: 2.9536
# Epoch 22/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.9479 - mape: 2.9479
# Epoch 23/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.9677 - mape: 2.9677
# Epoch 24/200
# 8/8 [==============================] - 0s 51ms/step - loss: 2.9306 - mape: 2.9306
# Epoch 25/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.9213 - mape: 2.9213
# Epoch 26/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.9216 - mape: 2.9216
# Epoch 27/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.8967 - mape: 2.8967
# Epoch 28/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.9302 - mape: 2.9302
# Epoch 29/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.9206 - mape: 2.9206
# Epoch 30/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.9562 - mape: 2.9562
# Epoch 31/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.9386 - mape: 2.9386
# Epoch 32/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.9566 - mape: 2.9566
# Epoch 33/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.9410 - mape: 2.9410
# Epoch 34/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.9292 - mape: 2.9292
# Epoch 35/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.8940 - mape: 2.8940
# Epoch 36/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.9042 - mape: 2.9042
# Epoch 37/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.8979 - mape: 2.8979
# Epoch 38/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.9192 - mape: 2.9192
# Epoch 39/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.8700 - mape: 2.8700
# Epoch 40/200
# 8/8 [==============================] - 0s 51ms/step - loss: 2.8539 - mape: 2.8539
# Epoch 41/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.8245 - mape: 2.8245
# Epoch 42/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.8664 - mape: 2.8664
# Epoch 43/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.8617 - mape: 2.8617
# Epoch 44/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.8618 - mape: 2.8618
# Epoch 45/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.8773 - mape: 2.8773
# Epoch 46/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.8357 - mape: 2.8357
# Epoch 47/200
# 8/8 [==============================] - 0s 53ms/step - loss: 2.8542 - mape: 2.8542
# Epoch 48/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.8769 - mape: 2.8769
# Epoch 49/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.8529 - mape: 2.8529
# Epoch 50/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.8232 - mape: 2.8232
# Epoch 51/200
# 8/8 [==============================] - 0s 54ms/step - loss: 2.8215 - mape: 2.8215
# Epoch 52/200
# 8/8 [==============================] - 0s 56ms/step - loss: 2.8476 - mape: 2.8476
# Epoch 53/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7980 - mape: 2.7980
# Epoch 54/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.7537 - mape: 2.7537
# Epoch 55/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7930 - mape: 2.7930
# Epoch 56/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.7970 - mape: 2.7970
# Epoch 57/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.7505 - mape: 2.7505
# Epoch 58/200
# 8/8 [==============================] - 0s 54ms/step - loss: 2.7647 - mape: 2.7647
# Epoch 59/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.7907 - mape: 2.7907
# Epoch 60/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.7602 - mape: 2.7602
# Epoch 61/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.7708 - mape: 2.7708
# Epoch 62/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7656 - mape: 2.7656
# Epoch 63/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.7512 - mape: 2.7512
# Epoch 64/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7037 - mape: 2.7037
# Epoch 65/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7169 - mape: 2.7169
# Epoch 66/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.7067 - mape: 2.7067
# Epoch 67/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7143 - mape: 2.7143
# Epoch 68/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6738 - mape: 2.6738
# Epoch 69/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6729 - mape: 2.6729
# Epoch 70/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6183 - mape: 2.6183
# Epoch 71/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.6616 - mape: 2.6616
# Epoch 72/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6650 - mape: 2.6650
# Epoch 73/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6613 - mape: 2.6613
# Epoch 74/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6628 - mape: 2.6628
# Epoch 75/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6415 - mape: 2.6415
# Epoch 76/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6412 - mape: 2.6412
# Epoch 77/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6743 - mape: 2.6743
# Epoch 78/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.6565 - mape: 2.6565
# Epoch 79/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6459 - mape: 2.6459
# Epoch 80/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6165 - mape: 2.6165
# Epoch 81/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6720 - mape: 2.6720
# Epoch 82/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6445 - mape: 2.6445
# Epoch 83/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6451 - mape: 2.6451
# Epoch 84/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6461 - mape: 2.6461
# Epoch 85/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6413 - mape: 2.6413
# Epoch 86/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6420 - mape: 2.6420
# Epoch 87/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6504 - mape: 2.6504
# Epoch 88/200
# 8/8 [==============================] - 0s 51ms/step - loss: 2.6551 - mape: 2.6551
# Epoch 89/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6536 - mape: 2.6536
# Epoch 90/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6551 - mape: 2.6551
# Epoch 91/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6646 - mape: 2.6646
# Epoch 92/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6522 - mape: 2.6522
# Epoch 93/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6203 - mape: 2.6203
# Epoch 94/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6325 - mape: 2.6325
# Epoch 95/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6189 - mape: 2.6189
# Epoch 96/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6330 - mape: 2.6330
# Epoch 97/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6235 - mape: 2.6235
# Epoch 98/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.5944 - mape: 2.5944
# Epoch 99/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.5472 - mape: 2.5472
# Epoch 100/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6053 - mape: 2.6053
# Epoch 101/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6069 - mape: 2.6069
# Epoch 102/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.5959 - mape: 2.5959
# Epoch 103/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6184 - mape: 2.6184
# Epoch 104/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6034 - mape: 2.6034
# Epoch 105/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.5838 - mape: 2.5838
# Epoch 106/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6280 - mape: 2.6280
# Epoch 107/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6226 - mape: 2.6226
# Epoch 108/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6034 - mape: 2.6034
# Epoch 109/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5869 - mape: 2.5869
# Epoch 110/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6209 - mape: 2.6209
# Epoch 111/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6134 - mape: 2.6134
# Epoch 112/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6117 - mape: 2.6117
# Epoch 113/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6139 - mape: 2.6139
# Epoch 114/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6211 - mape: 2.6211
# Epoch 115/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6042 - mape: 2.6042
# Epoch 116/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6312 - mape: 2.6312
# Epoch 117/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6247 - mape: 2.6247
# Epoch 118/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6303 - mape: 2.6303
# Epoch 119/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6296 - mape: 2.6296
# Epoch 120/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6479 - mape: 2.6479
# Epoch 121/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6300 - mape: 2.6300
# Epoch 122/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6120 - mape: 2.6120
# Epoch 123/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6113 - mape: 2.6113
# Epoch 124/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6033 - mape: 2.6033
# Epoch 125/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6183 - mape: 2.6183
# Epoch 126/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6182 - mape: 2.6182
# Epoch 127/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.5906 - mape: 2.5906
# Epoch 128/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.5555 - mape: 2.5555
# Epoch 129/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.5826 - mape: 2.5826
# Epoch 130/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.5961 - mape: 2.5961
# Epoch 131/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.5984 - mape: 2.5984
# Epoch 132/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.6119 - mape: 2.6119
# Epoch 133/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6050 - mape: 2.6050
# Epoch 134/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.5781 - mape: 2.5781
# Epoch 135/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6195 - mape: 2.6195
# Epoch 136/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6304 - mape: 2.6304
# Epoch 137/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6116 - mape: 2.6116
# Epoch 138/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6011 - mape: 2.6011
# Epoch 139/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6110 - mape: 2.6110
# Epoch 140/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6290 - mape: 2.6290
# Epoch 141/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6296 - mape: 2.6296
# Epoch 142/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6288 - mape: 2.6288
# Epoch 143/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6365 - mape: 2.6365
# Epoch 144/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6296 - mape: 2.6296
# Epoch 145/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6540 - mape: 2.6540
# Epoch 146/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6409 - mape: 2.6409
# Epoch 147/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6598 - mape: 2.6598
# Epoch 148/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6517 - mape: 2.6517
# Epoch 149/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6673 - mape: 2.6673
# Epoch 150/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6470 - mape: 2.6470
# Epoch 151/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6452 - mape: 2.6452
# Epoch 152/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6272 - mape: 2.6272
# Epoch 153/200
# 8/8 [==============================] - 0s 52ms/step - loss: 2.6187 - mape: 2.6187
# Epoch 154/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.6267 - mape: 2.6267
# Epoch 155/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.6521 - mape: 2.6521
# Epoch 156/200
# 8/8 [==============================] - 0s 55ms/step - loss: 2.5981 - mape: 2.5981
# Epoch 157/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.5872 - mape: 2.5872
# Epoch 158/200
# 8/8 [==============================] - 0s 52ms/step - loss: 2.5725 - mape: 2.5725
# Epoch 159/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6038 - mape: 2.6038
# Epoch 160/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6035 - mape: 2.6035
# Epoch 161/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.6033 - mape: 2.6033
# Epoch 162/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6103 - mape: 2.6103
# Epoch 163/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.5817 - mape: 2.5817
# Epoch 164/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6062 - mape: 2.6062
# Epoch 165/200
# 8/8 [==============================] - 0s 51ms/step - loss: 2.6237 - mape: 2.6237
# Epoch 166/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6036 - mape: 2.6036
# Epoch 167/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6037 - mape: 2.6037
# Epoch 168/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.5855 - mape: 2.5855
# Epoch 169/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6218 - mape: 2.6218
# Epoch 170/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6143 - mape: 2.6143
# Epoch 171/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6130 - mape: 2.6130
# Epoch 172/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6161 - mape: 2.6161
# Epoch 173/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6047 - mape: 2.6047
# Epoch 174/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6384 - mape: 2.6384
# Epoch 175/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6226 - mape: 2.6226
# Epoch 176/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6385 - mape: 2.6385
# Epoch 177/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6322 - mape: 2.6322
# Epoch 178/200
# 8/8 [==============================] - 0s 33ms/step - loss: 2.6486 - mape: 2.6486
# Epoch 179/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6387 - mape: 2.6387
# Epoch 180/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6355 - mape: 2.6355
# Epoch 181/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6133 - mape: 2.6133
# Epoch 182/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6242 - mape: 2.6242
# Epoch 183/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6158 - mape: 2.6158
# Epoch 184/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6451 - mape: 2.6451
# Epoch 185/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6067 - mape: 2.6067
# Epoch 186/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.5874 - mape: 2.5874
# Epoch 187/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.5660 - mape: 2.5660
# Epoch 188/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6138 - mape: 2.6138
# Epoch 189/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6081 - mape: 2.6081
# Epoch 190/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6077 - mape: 2.6077
# Epoch 191/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6231 - mape: 2.6231
# Epoch 192/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.5881 - mape: 2.5881
# Epoch 193/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6061 - mape: 2.6061
# Epoch 194/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6268 - mape: 2.6268
# Epoch 195/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.6192 - mape: 2.6192
# Epoch 196/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6095 - mape: 2.6095
# Epoch 197/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.5869 - mape: 2.5869
# Epoch 198/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6383 - mape: 2.6383
# Epoch 199/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6203 - mape: 2.6203
# Epoch 200/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6217 - mape: 2.6217
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (4096, 1, 32)             5248
#
#  lstm_5 (LSTM)               (4096, 1, 32)             8320
#
#  dense_4 (Dense)             (4096, 1, 16)             528
#
#  dense_5 (Dense)             (4096, 1, 1)              17
#
# =================================================================
# Total params: 14,113
# Trainable params: 14,113
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 8/8 [==============================] - 3s 45ms/step - loss: 99.2377 - mape: 99.2377
# Epoch 2/200
# 8/8 [==============================] - 0s 45ms/step - loss: 96.1632 - mape: 96.1632
# Epoch 3/200
# 8/8 [==============================] - 0s 44ms/step - loss: 93.1636 - mape: 93.1636
# Epoch 4/200
# 8/8 [==============================] - 0s 43ms/step - loss: 89.8318 - mape: 89.8318
# Epoch 5/200
# 8/8 [==============================] - 0s 44ms/step - loss: 85.6578 - mape: 85.6578
# Epoch 6/200
# 8/8 [==============================] - 0s 45ms/step - loss: 79.9081 - mape: 79.9081
# Epoch 7/200
# 8/8 [==============================] - 0s 47ms/step - loss: 72.2231 - mape: 72.2231
# Epoch 8/200
# 8/8 [==============================] - 0s 46ms/step - loss: 61.1286 - mape: 61.1286
# Epoch 9/200
# 8/8 [==============================] - 0s 49ms/step - loss: 45.2354 - mape: 45.2354
# Epoch 10/200
# 8/8 [==============================] - 0s 53ms/step - loss: 23.1848 - mape: 23.1848
# Epoch 11/200
# 8/8 [==============================] - 0s 49ms/step - loss: 6.9905 - mape: 6.9905
# Epoch 12/200
# 8/8 [==============================] - 0s 47ms/step - loss: 6.2861 - mape: 6.2861
# Epoch 13/200
# 8/8 [==============================] - 0s 45ms/step - loss: 4.3026 - mape: 4.3026
# Epoch 14/200
# 8/8 [==============================] - 0s 43ms/step - loss: 3.2633 - mape: 3.2633
# Epoch 15/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7873 - mape: 2.7873
# Epoch 16/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.8690 - mape: 2.8690
# Epoch 17/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.6847 - mape: 2.6847
# Epoch 18/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7882 - mape: 2.7882
# Epoch 19/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.7128 - mape: 2.7128
# Epoch 20/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7358 - mape: 2.7358
# Epoch 21/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6914 - mape: 2.6914
# Epoch 22/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.7150 - mape: 2.7150
# Epoch 23/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.7186 - mape: 2.7186
# Epoch 24/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.7193 - mape: 2.7193
# Epoch 25/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.7061 - mape: 2.7061
# Epoch 26/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7129 - mape: 2.7129
# Epoch 27/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6887 - mape: 2.6887
# Epoch 28/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.7221 - mape: 2.7221
# Epoch 29/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.7116 - mape: 2.7116
# Epoch 30/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7300 - mape: 2.7300
# Epoch 31/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7152 - mape: 2.7152
# Epoch 32/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.7333 - mape: 2.7333
# Epoch 33/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7220 - mape: 2.7220
# Epoch 34/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7140 - mape: 2.7140
# Epoch 35/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6837 - mape: 2.6837
# Epoch 36/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6944 - mape: 2.6944
# Epoch 37/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6882 - mape: 2.6882
# Epoch 38/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.7104 - mape: 2.7104
# Epoch 39/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6680 - mape: 2.6680
# Epoch 40/200
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6524 - mape: 2.6524
# Epoch 41/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6261 - mape: 2.6261
# Epoch 42/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6679 - mape: 2.6679
# Epoch 43/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6672 - mape: 2.6672
# Epoch 44/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6679 - mape: 2.6679
# Epoch 45/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6644 - mape: 2.6644
# Epoch 46/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6540 - mape: 2.6540
# Epoch 47/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6655 - mape: 2.6655
# Epoch 48/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6749 - mape: 2.6749
# Epoch 49/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6651 - mape: 2.6651
# Epoch 50/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6552 - mape: 2.6552
# Epoch 51/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6457 - mape: 2.6457
# Epoch 52/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6789 - mape: 2.6789
# Epoch 53/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6375 - mape: 2.6375
# Epoch 54/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6614 - mape: 2.6614
# Epoch 55/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6632 - mape: 2.6632
# Epoch 56/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.6699 - mape: 2.6699
# Epoch 57/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.6507 - mape: 2.6507
# Epoch 58/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6693 - mape: 2.6693
# Epoch 59/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6840 - mape: 2.6840
# Epoch 60/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6690 - mape: 2.6690
# Epoch 61/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.6835 - mape: 2.6835
# Epoch 62/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6821 - mape: 2.6821
# Epoch 63/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.6746 - mape: 2.6746
# Epoch 64/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.6371 - mape: 2.6371
# Epoch 65/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.6443 - mape: 2.6443
# Epoch 66/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6578 - mape: 2.6578
# Epoch 67/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6649 - mape: 2.6649
# Epoch 68/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.6249 - mape: 2.6249
# Epoch 69/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.6245 - mape: 2.6245
# Epoch 70/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.5795 - mape: 2.5795
# Epoch 71/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.6221 - mape: 2.6221
# Epoch 72/200
# 8/8 [==============================] - 0s 35ms/step - loss: 2.6253 - mape: 2.6253
# Epoch 73/200
# ...
# Epoch 13/200
# 8/8 [==============================] - 0s 39ms/step - loss: 14.8953 - mape: 14.8953
# Epoch 14/200
# 8/8 [==============================] - 0s 44ms/step - loss: 6.2300 - mape: 6.2300
# Epoch 15/200
# 8/8 [==============================] - 0s 49ms/step - loss: 4.5084 - mape: 4.5084
# Epoch 16/200
# 8/8 [==============================] - 0s 47ms/step - loss: 4.4093 - mape: 4.4093
# Epoch 17/200
# 8/8 [==============================] - 0s 48ms/step - loss: 3.5241 - mape: 3.5241
# Epoch 18/200
# 8/8 [==============================] - 0s 39ms/step - loss: 3.0092 - mape: 3.0092
# Epoch 19/200
# 8/8 [==============================] - 0s 43ms/step - loss: 3.2327 - mape: 3.2327
# Epoch 20/200
# 8/8 [==============================] - 0s 53ms/step - loss: 2.9759 - mape: 2.9759
# Epoch 21/200
# 8/8 [==============================] - 0s 47ms/step - loss: 3.0812 - mape: 3.0812
# Epoch 22/200
# 8/8 [==============================] - 0s 40ms/step - loss: 3.0022 - mape: 3.0022
# Epoch 23/200
# 8/8 [==============================] - 0s 47ms/step - loss: 3.0215 - mape: 3.0215
# Epoch 24/200
# 8/8 [==============================] - 0s 38ms/step - loss: 3.0065 - mape: 3.0065
# Epoch 25/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.9761 - mape: 2.9761
# Epoch 26/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.9808 - mape: 2.9808
# Epoch 27/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.9486 - mape: 2.9486
# Epoch 28/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.9930 - mape: 2.9930
# Epoch 29/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.9760 - mape: 2.9760
# Epoch 30/200
# 8/8 [==============================] - 0s 40ms/step - loss: 3.0205 - mape: 3.0205
# Epoch 31/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.9917 - mape: 2.9917
# Epoch 32/200
# 8/8 [==============================] - 0s 49ms/step - loss: 3.0276 - mape: 3.0276
# Epoch 33/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.9874 - mape: 2.9874
# Epoch 34/200
# 8/8 [==============================] - 0s 52ms/step - loss: 2.9761 - mape: 2.9761
# Epoch 35/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.9376 - mape: 2.9376
# Epoch 36/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.9384 - mape: 2.9384
# Epoch 37/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.8977 - mape: 2.8977
# Epoch 38/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.8816 - mape: 2.8816
# Epoch 39/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7894 - mape: 2.7894
# Epoch 40/200
# 8/8 [==============================] - 0s 29ms/step - loss: 2.7760 - mape: 2.7760
# Epoch 41/200
# 8/8 [==============================] - 0s 31ms/step - loss: 2.7686 - mape: 2.7686
# Epoch 42/200
# 8/8 [==============================] - 0s 36ms/step - loss: 2.7627 - mape: 2.7627
# Epoch 43/200
# 8/8 [==============================] - 0s 54ms/step - loss: 2.7216 - mape: 2.7216
# Epoch 44/200
# 8/8 [==============================] - 0s 51ms/step - loss: 2.7225 - mape: 2.7225
# Epoch 45/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.7277 - mape: 2.7277
# Epoch 46/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.7087 - mape: 2.7087
# Epoch 47/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.7119 - mape: 2.7119
# Epoch 48/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7405 - mape: 2.7405
# Epoch 49/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7278 - mape: 2.7278
# Epoch 50/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7036 - mape: 2.7036
# Epoch 51/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7041 - mape: 2.7041
# Epoch 52/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7546 - mape: 2.7546
# Epoch 53/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.7129 - mape: 2.7129
# Epoch 54/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.7316 - mape: 2.7316
# Epoch 55/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.7327 - mape: 2.7327
# Epoch 56/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7304 - mape: 2.7304
# Epoch 57/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7224 - mape: 2.7224
# Epoch 58/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.7492 - mape: 2.7492
# Epoch 59/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.7409 - mape: 2.7409
# Epoch 60/200
# 8/8 [==============================] - 0s 37ms/step - loss: 2.7203 - mape: 2.7203
# Epoch 61/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7745 - mape: 2.7745
# Epoch 62/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7429 - mape: 2.7429
# Epoch 63/200
# 8/8 [==============================] - 0s 59ms/step - loss: 2.7296 - mape: 2.7296
# Epoch 64/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6948 - mape: 2.6948
# Epoch 65/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7134 - mape: 2.7134
# Epoch 66/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.7060 - mape: 2.7060
# Epoch 67/200
# 8/8 [==============================] - 0s 52ms/step - loss: 2.7166 - mape: 2.7166
# Epoch 68/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.7046 - mape: 2.7046
# Epoch 69/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.6902 - mape: 2.6902
# Epoch 70/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6274 - mape: 2.6274
# Epoch 71/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.6875 - mape: 2.6875
# Epoch 72/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7052 - mape: 2.7052
# Epoch 73/200
# 8/8 [==============================] - 0s 56ms/step - loss: 2.7052 - mape: 2.7052
# Epoch 74/200
# 8/8 [==============================] - 0s 34ms/step - loss: 2.6943 - mape: 2.6943
# Epoch 75/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6993 - mape: 2.6993
# Epoch 76/200
# 8/8 [==============================] - 0s 54ms/step - loss: 2.6881 - mape: 2.6881
# Epoch 77/200
# 8/8 [==============================] - 0s 39ms/step - loss: 2.7127 - mape: 2.7127
# Epoch 78/200
# 8/8 [==============================] - 0s 44ms/step - loss: 2.7019 - mape: 2.7019
# Epoch 79/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.6952 - mape: 2.6952
# Epoch 80/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6612 - mape: 2.6612
# Epoch 81/200
# 8/8 [==============================] - 0s 48ms/step - loss: 2.7237 - mape: 2.7237
# Epoch 82/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.7022 - mape: 2.7022
# Epoch 83/200
# 8/8 [==============================] - 0s 46ms/step - loss: 2.7090 - mape: 2.7090
# Epoch 84/200
# 8/8 [==============================] - 0s 40ms/step - loss: 2.7093 - mape: 2.7093
# Epoch 85/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.7082 - mape: 2.7082
# Epoch 86/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.7129 - mape: 2.7129
# Epoch 87/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.7181 - mape: 2.7181
# Epoch 88/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.7148 - mape: 2.7148
# Epoch 89/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.7336 - mape: 2.7336
# Epoch 90/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.7283 - mape: 2.7283
# Epoch 91/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.7371 - mape: 2.7371
# Epoch 92/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.7238 - mape: 2.7238
# Epoch 93/200
# 8/8 [==============================] - 0s 38ms/step - loss: 2.7121 - mape: 2.7121
# Epoch 94/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.7235 - mape: 2.7235
# Epoch 95/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.7001 - mape: 2.7001
# Epoch 96/200
# 8/8 [==============================] - 0s 50ms/step - loss: 2.6965 - mape: 2.6965
# Epoch 97/200
# 8/8 [==============================] - 0s 52ms/step - loss: 2.7088 - mape: 2.7088
# Epoch 98/200
# 8/8 [==============================] - 0s 47ms/step - loss: 2.6760 - mape: 2.6760
# Epoch 99/200
# 8/8 [==============================] - 0s 55ms/step - loss: 2.6120 - mape: 2.6120
# Epoch 100/200
# 8/8 [==============================] - 0s 51ms/step - loss: 2.6807 - mape: 2.6807
# Epoch 101/200
# 8/8 [==============================] - 0s 49ms/step - loss: 2.6804 - mape: 2.6804
# Epoch 102/200
# 8/8 [==============================] - 0s 43ms/step - loss: 2.6703 - mape: 2.6703
# Epoch 103/200
# 1/8 [==>...........................] - ETA: 0s - loss: 3.4259 - mape: 3.4259
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Edmilson\Downloads\mestrado\waterdemand\SVR-RNN_Model_general.ipynb Cell 11 in <cell line: 33>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=34'>35</a> for N_Nos_Layer2 in range (32,6,-8):
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a>   for N_Nos_Layer3 in range (32,6,-8):
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=36'>37</a>     #Chama a função de treinamento da LSTM com os hiperparâmetros selecionados para cada iteração
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=37'>38</a>     MAPE, model = treinar_LSTM(X_train, y_train, N_Nos_Layer1, N_Nos_Layer2, N_Nos_Layer3, EPOCAS, batch_size)
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=38'>39</a>     #armazena o melhor modelo, com o menor MAPE
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=39'>40</a>     if(bestModel.MAPE > MAPE):
#
# c:\Users\Edmilson\Downloads\mestrado\waterdemand\SVR-RNN_Model_general.ipynb Cell 11 in treinar_LSTM(X_train, y_train, N_Nos_Layer1, N_Nos_Layer2, N_Nos_Layer3, EPOCAS, batch_size)
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=20'>21</a> model.summary()
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=21'>22</a> steps_per_epoch = len(train_feature) // batch_size
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=22'>23</a> history = model.fit(train_data, epochs=EPOCAS, steps_per_epoch = steps_per_epoch)
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=24'>25</a> val_feature = np.array(X_train).reshape((X_train.shape[0], 1, X_train.shape[1]))
#      <a href='vscode-notebook-cell:/c%3A/Users/Edmilson/Downloads/mestrado/waterdemand/SVR-RNN_Model_general.ipynb#X15sZmlsZQ%3D%3D?line=25'>26</a> val_label = np.array(y_train).reshape((y_train.shape[0], 1, 1))
#
# File c:\Python\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\lib\site-packages\keras\engine\training.py:1216, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1209 with tf.profiler.experimental.Trace(
#    1210     'train',
#    1211     epoch_num=epoch,
#    1212     step_num=step,
#    1213     batch_size=batch_size,
#    1214     _r=1):
#    1215   callbacks.on_train_batch_begin(step)
# -> 1216   tmp_logs = self.train_function(iterator)
#    1217   if data_handler.should_sync:
#    1218     context.async_wait()
#
# File c:\Python\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\lib\site-packages\tensorflow\python\eager\def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Python\lib\site-packages\tensorflow\python\eager\def_function.py:942, in Function._call(self, *args, **kwds)
#     939   self._lock.release()
#     940   # In this case we have created variables on the first call, so we run the
#     941   # defunned version which is guaranteed to never create variables.
# --> 942   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943 elif self._stateful_fn is not None:
#     944   # Release the lock early so that multiple threads can perform the call
#     945   # in parallel.
#     946   self._lock.release()
#
# File c:\Python\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function.__call__(self, *args, **kwargs)
#    3127 with self._lock:
#    3128   (graph_function,
#    3129    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130 return graph_function._call_flat(
#    3131     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Python\lib\site-packages\tensorflow\python\eager\function.py:1959, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1955 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1956 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1957     and executing_eagerly):
#    1958   # No tape is watching; skip to running the function.
# -> 1959   return self._build_call_outputs(self._inference_function.call(
#    1960       ctx, args, cancellation_manager=cancellation_manager))
#    1961 forward_backward = self._select_forward_and_backward_functions(
#    1962     args,
#    1963     possible_gradient_type,
#    1964     executing_eagerly)
#    1965 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Python\lib\site-packages\tensorflow\python\eager\function.py:598, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     596 with _InterpolateFunctionError(self):
#     597   if cancellation_manager is None:
# --> 598     outputs = execute.execute(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#     601         inputs=args,
#     602         attrs=attrs,
#     603         ctx=ctx)
#     604   else:
#     605     outputs = execute.execute_with_cancellation(
#     606         str(self.signature.name),
#     607         num_outputs=self._num_outputs,
#    (...)
#     610         ctx=ctx,
#     611         cancellation_manager=cancellation_manager)
#
# File c:\Python\lib\site-packages\tensorflow\python\eager\execute.py:58, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56 try:
#      57   ctx.ensure_initialized()
# ---> 58   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                       inputs, attrs, num_outputs)
#      60 except core._NotOkStatusException as e:
#      61   if name is not None:
#
# KeyboardInterrupt:

# %%
bestModel.show()

# %%
MAPE, predict, y_label = previsao_LSTM(X_test, y_test, bestModel.model, batch_size)

# %%
#Estimate Et for treinam and test
# For treinam data
Lt_train = grid.predict(X_train)
Yt_train = y_train
Et_train = Yt_train - Lt_train

# For test data
Lt_test = predict
Yt_test = y_test
Et_test = Yt_test - Lt_test

# %%
# MAPE statistics for test data
((np.mean(np.abs(Yt_test - Lt_test) / (Yt_test)))) * 100
# Out:
# 3.319429893123213

# %%
# MAPE statistics for treinam data
((np.mean(np.abs(Yt_train - Lt_train) / (Yt_train)))) * 100
# Out:
# 2.4860142953804063

# %%
#create  dataframe of Et value
df_Et = pd.DataFrame(Et_train, columns=['VL_Et'])

for n_step in range(1,n_time_steps+1,1):
    df_Et['vl-'+str(n_step)]=df_Et['VL_Et'].shift(n_step)  

#drop rows with null values
df_Et.dropna(inplace=True)

Nt_train = df_Et['VL_Et']

df_Et.drop(['VL_Et'],axis=1, inplace=True)

X_train = df_Et
y_train = Nt_train

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow import data

# MLP model for hybrid prediction for non linear component Et_train 

#Split dataset in treinam /  75% treinam  25% test
nlinhas = int(np.round(X_train.shape[0] * 0.75)) # 
  
max_size_train_split = int(np.round(nlinhas / 5)) 
max_size__test_split = int(np.round((X_train.shape[0] - nlinhas) / 5))
size_split = 5
  
# Cross-validated for time series
ts_cv_mlp = TimeSeriesSplit(
      n_splits=size_split, # Number of divisions
      max_train_size=max_size_train_split,    # maximum size of each set. of training
      gap=2, # number of samples to exclude between each training and testing set
      test_size=max_size__test_split, # maximum size of each set. of test.
)

param_grid = {
     'hidden_layer_sizes': [(4,6,1),(2,6,1),(6,12,1),(6,18,1)], # MLP layers
     'max_iter': [ 500], # maximum iterations
     'activation': [ 'relu','identity'], # activation function
     'solver': ['adam'], # weight optimization algorithm
     'alpha': [0.0001, 0.001, 0.01],  # alpha strength of regularization
}
  
#modelo = MLPRegressor(random_state=0)
model = Sequential()
model.add(SimpleRNN(hidden_units, input_shape=input_shape, 
                        activation=activation[0]))
model.add(Dense(units=dense_units, activation=activation[1]))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

grid_mlp = GridSearchCV(modelo, param_grid, n_jobs= -1,scoring='neg_mean_absolute_percentage_error', cv=ts_cv_mlp, verbose=1)
grid_mlp.fit(np.array(X_train), np.array(y_train))

resultado = str(grid.best_params_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
#MAPE to Et predicted on MLP Model
predict=grid_mlp.predict(X_train)  
((np.mean(np.abs(y_train - predict) / (y_train)))) * 100
# Out:
# c:\Python\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# 176.17760618927858

# %%
# Recomposition of Nt + Lt form train data
Lt_train2 = Lt_train[n_time_steps:len(Lt_train)]
Yt_train2 = Yt_train[n_time_steps:len(Yt_train)]
Yt_train_predicted = predict + Lt_train2
((np.mean(np.abs(Yt_train2 - Yt_train_predicted) / (Yt_train2)))) * 100
# Out:
# 2.4931560386218705

# %%
y_test = Yt_train2
predict = Yt_train_predicted

# %%
#O gráfico abaixo mostra os valores reais em preto e os valores prditos em azul
npredicts=1000
pyplot.figure(figsize=(10,7)) 
pyplot.scatter(np.arange(0,y_test.shape[0],1)[0:npredicts],np.array(y_test)[0:npredicts], color = 'black')
pyplot.plot(np.arange(0,predict.shape[0],1)[0:npredicts], np.array(predict)[0:npredicts], color = 'blue', linewidth=2)
pyplot.xlabel('n seq.')
pyplot.ylabel('consumo l/h')
pyplot.show()

# %%
# For test data
#Lt_test = predict
#Yt_test = y_test
#Et_test = Yt_test - Lt_test


#create  dataframe of Et value
df_Et = pd.DataFrame(Et_test, columns=['VL_Et'])

for n_step in range(1,n_time_steps+1,1):
    df_Et['vl-'+str(n_step)]=df_Et['VL_Et'].shift(n_step)  

#drop rows with null values
df_Et.dropna(inplace=True)

Nt_test = df_Et['VL_Et']

df_Et.drop(['VL_Et'],axis=1, inplace=True)

X_test = df_Et
y_test = Nt_test

#MAPE to Et predicted on MLP Model
predict=grid_mlp.predict(X_test)  
MAPE_Nt_test = ((np.mean(np.abs(y_test - predict) / (y_test)))) * 100

# Recomposition of Nt + Lt form test data
Lt_test2 = Lt_test[n_time_steps:len(Lt_test)]
Yt_test2 = Yt_test[n_time_steps:len(Yt_test)]
Yt_test_predicted = predict + Lt_test2
MAPE = ((np.mean(np.abs(Yt_test2 - Yt_test_predicted) / (Yt_test2)))) * 100
print('MAPE',MAPE, ' MAPE_Nt_test',MAPE_Nt_test)
# Out:
# MAPE 3.3811686878982563  MAPE_Nt_test 126.7515475432811
# c:\Python\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(

# %%
y_test = Yt_test2
predict = Yt_test_predicted

# %%
#Validação dos resultados

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error

#Erro médio quadrático  (diferença quadrática média entre os valores estimados e valores reais) - MSE
mean_squared_error(y_test, predict)
# Out:
# 269834.3326230365

# %%
#Raiz quadrada do Erro médio - RMSE
np.sqrt(mean_squared_error(y_test, predict))
# Out:
# 519.4558043019988

# %%
#Distância absoluta média ou Erro médio absoluto - MAE
median_absolute_error(y_pred=predict, y_true = y_test)
# Out:
# 128.65000777800196

# %%
#Calcular o MAPE (Erro médio percentual absoluto)
MAPE = ((np.mean(np.abs(y_test -predict) / (y_test)))) * 100
MAPE
# Out:
# 3.3811686878982563
